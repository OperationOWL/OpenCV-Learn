# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('giraffes.jpg', 0)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
ret, img2 = cv2.threshold(img, 127, 256, cv2.THRESH_BINARY)

# %%
plt.imshow(img2, cmap = 'gray')

# %%
img_hsv = cv2.imread('giraffes.jpg')
img_hsv = cv2.cvtColor(img_hsv, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img_hsv)
